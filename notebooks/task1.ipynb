# %% [markdown]
# # Resting-State ROI Time-Series Visualization (DLPFC & ACC)
#
# > Starter notebook for non-specialized, no-login workflow. Fill in preprocessing, ROI extraction, QC metrics, and plotting.
#
# **Licenses & Citations**
# - Code: MIT (see `LICENSE`).
# - Content: CC BY 4.0.
# - Datasets/Atlases: Cite and verify licenses (e.g., Nilearn `fetch_development_fmri`, `fetch_coords_dosenbach_2010`).
#
# **Checklist**
# - [ ] Document TR and number of volumes (N)
# - [ ] Apply detrend, band-pass (0.01–0.1 Hz), standardize=zscore
# - [ ] Regress motion/confounds if available
# - [ ] Extract spherical ROIs (radius=6 mm) for DLPFC & ACC using Dosenbach 2010 coords
# - [ ] Compute QC: mean FD, %FD>0.2mm, tSNR per ROI, corr(DLPFC,ACC)
# - [ ] Plot time series (seconds on x-axis) and save as `task1.png`

# %%
import numpy as np
import matplotlib.pyplot as plt
from nilearn import datasets
print('Environment OK. numpy/matplotlib/nilearn imported.')

# %%
# TODO: Data fetch (example):
# dev = datasets.fetch_development_fmri(n_subjects=1)
# print(dev)

# TODO: Dosenbach coords:
# coords = datasets.fetch_coords_dosenbach_2010()
# print(coords.keys())

# %% [markdown]
# ## Next Steps
# 1. Implement preprocessing with nilearn's cleaning utilities.
# 2. Extract ROI signals using 6mm spheres at selected DLPFC/ACC nodes.
# 3. Compute QC metrics and construct Ethercalc row.
# 4. Plot and save `task1.png`.
